# %%
import xlutils
import xlrd 
import xlwt
import sys

# Give the location of the file 
loc = ("Filtered.brain.xlsx") 
  
# To open Workbook 
wb = xlrd.open_workbook(loc) 
sheet = wb.sheet_by_index(0) 

#print(sheet.nrows)
#print(sheet.ncols)

nrows = sheet.nrows
ncols = sheet.ncols
# print (range(nrows))
# print (range(ncols))
#for i in range(nrows): 
#    print(sheet.cell_value(i, 0)) 

# book = xlwt.Workbook()
# sheet1 = book.add_sheet("intensitySheet1")

orig_stdout = sys.stdout
# f = open('filtered_6005_out.csv', 'w')
f = open('cellnumber.csv', 'w')
sys.stdout = f

# For row 0 and column 0 
for i in range(0, 6004):
#     print("i = {}".format(i))
    for j in range(0, 139):
#          print("j = {}".format(j))
#          sheet1.write(i, j, sheet.cell_value(i, j))
#        print(sheet.cell_value(i, j) )
        print(i+1)
# book.save("valuforintensity.xlsx")           

sys.stdout = orig_stdout
f.close()

# %%
import xlutils
import xlrd 
import xlwt
import sys

loc = ("results2_filtered_max.xlsx") 

wb = xlrd.open_workbook(loc) 
sheet = wb.sheet_by_index(0)

nrows = sheet.nrows
ncols = sheet.ncols

print(nrows, ncols)


orig_stdout = sys.stdout
f = open('results2_filtered_max_out.csv', 'w')
sys.stdout = f

for i in range (1,nrows):
    for j in range(0,ncols):
#         value = sheet.cell(i,j)
        row = sheet.row(i)
        print(row[j].value)
sys.stdout = orig_stdout
f.close()
# Out:
# 1031 110

# %% [markdown]
# #### import xlutils
# import xlrd
# import sys
#
# # Give the location of the file
# loc = ("time_courses.xlsx")
#
# # To open Workbook
# wb = xlrd.open_workbook(loc)
# sheet = wb.sheet_by_index(0)
#
# #print(sheet.nrows)
# #print(sheet.ncols)
#
# nrows = sheet.nrows
# ncols = sheet.ncols
#
# orig_stdout = sys.stdout
# f = open('intensity_1388_out_with_timestep2.csv', 'w')
# sys.stdout = f
#
# # For row 0 and column 0
# for i in range(1, 1389):
# #     print("i = {}".format(i))
#     for j in range(0, 139):
# #          print("j = {}".format(j))
# #          sheet1.write(i, j, sheet.cell_value(i, j))
#        print(i,"\t",sheet.cell_value(i, j) )
# # book.save("valuforintensity.xlsx")
#
# sys.stdout = orig_stdout
# f.close()

# %%
from scipy.interpolate import interp1d

import xlutils
import xlrd 
import sys

m = interp1d([1,1031],[25,-25])

orig_stdout = sys.stdout
# f = open('filtered_6005_out.csv', 'w')
f = open('zvalue_opposite_results2.csv', 'w')
sys.stdout = f

# For row 0 and column 0 
for i in range(1, 1031):
    for j in range(0, 110):
        print(m(i))
          
sys.stdout = orig_stdout
f.close()
